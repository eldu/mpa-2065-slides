# %% [markdown]
# <center><h1>Introduction to ggplot2</h1></center>
# <center><h3>Ellen Duong</h3></center>
# <center><h3>Paul Stey</h3></center>
# <center><h3>2023-10-12</h3></center>

# %% [markdown]
# # 1. What is _ggplot2_?
#
#   - Hugely popular R package for visualization
#   - Authored by Hadley Wickham (of _dplyr_ and _tidyverse_ fame)
#   - Implements the "grammar-of-graphics" design philosophy (hence "gg")
#   - Easily produces beautiful and informative visualizations

# %% [markdown]
# # 2. Plotting Person-Level Characteristics in Arrests
#
#   - The Pvd arrests data are at the _violation_-level
#   - We want person-level data on the invdividuals arrested
#   - This "_level-of-analysis_" or "_level-of-granularity_" problem is ubiquitous

# %% [markdown]
# # 3. Generating Person-Level Data
#   - We are aggregating "up" from the violation level
#   - Will use the `group_by()` and `summarise()` idiom

# %%
# Load necessary packages
library(stringr)
library(dplyr)
library(ggplot2)

arrests_df <- read.csv("data/pvd_arrests_2021-10-03.csv")

# %%
head(arrests_df)
# Out:
#   arrest_date           year month gender race  ethnicity   year_of_birth age
# 1 2019-08-24T02:23:00.0 2019 8     Male   White NonHispanic 1981          37
# 2 2019-08-24T02:02:00.0 2019 8                              1994          25
# 3 2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984          34
# 4 2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984          34
# 5 2019-08-24T02:02:00.0 2019 8     Female Black Unknown     2001          18
# 6 2019-08-24T02:02:00.0 2019 8     Female Black Unknown     2001          18
#   from_address         from_city  from_state   statute_type
# 1 No Permanent Address providence Rhode Island
# 2 SUMMER AVE           Cranston   Rhode Island RI Statute Violation
# 3 DOUGLAS AVE          Providence Rhode Island RI Statute Violation
# 4 DOUGLAS AVE          Providence Rhode Island RI Statute Violation
# 5 TRASH ST                                     RI Statute Violation
# 6 TRASH ST                                     RI Statute Violation
#   statute_code statute_desc                                              counts
# 1                                                                        NA
# 2 31-11-18     Driving after Denial, Suspension or Revocation of License  1
# 3 12-7-10      RESISTING LEGAL OR ILLEGAL ARREST                          1
# 4 11-45-1      DISORDERLY CONDUCT                                         1
# 5 12-7-10      RESISTING LEGAL OR ILLEGAL ARREST                          1
# 6 11-45-1      DISORDERLY CONDUCT                                         1
#   case_number   arresting_officers       id
# 1 2019-00084142  YGonzalez, LTaveras     pvd2218242150382148273
# 2 2019-00084127  NManfredi               pvd15166785558364246202
# 3 2019-00084126  MPlace, JPerez, ASantos pvd3142917706201385905
# 4 2019-00084126  MPlace, JPerez, ASantos pvd3142917706201385905
# 5 2019-00084126  MPlace, JPerez, ASantos pvd460449304532374599
# 6 2019-00084126  MPlace, JPerez, ASantos pvd460449304532374599

# %% [markdown]
# ## 3.1 Computing Number of Officers (correctly)
#
#   - First, need to determine if `arresting_officers` is in _full-name_-format or _first-initial_-format

# %%
is_uppercase <- function(chr) {
    res <- chr %in% LETTERS
    return(res)
}

has_full_names <- function(names_str) {
    char1 <- str_sub(names_str, 1, 1)
    char2 <- str_sub(names_str, 2, 2)
    
    res <- !(is_uppercase(char1) && is_uppercase(char2))
    return(res)
}

# %% [markdown]
# ### 3.1.1 Counting the Names
#   - Want to correct count names regardless of format
#   - Update our `count_names()` function

# %%
count_names <- function(names_str) {
    names_str_trm <- str_trim(names_str)     # remove whitespace
    
    if (has_full_names(names_str_trm)) {
        split_char <- "/ "
    } else {
        split_char <- ", "
    }
    
    name_list <- str_split(names_str_trm, split_char)
    
    name_vec <- unlist(name_list)
    
    k <- length(name_vec)
    
    return(k)
}

# %% [markdown]
# ### 3.1.2 Counting Officers (correctly)
#   - Note the sequence of function calls:
#     + `count_all_names()` => `count_names()` => `has_full_names()` => `is_uppercase()`

# %%
count_all_names <- function(col) {

    n <- length(col)   # get the length of our input column
    cnts <- rep(0, n)  # allocate vector of zeros to populate with counts

    for (i in 1:n) {
        cnts[i] <- count_names(col[i])
    }
    return(cnts) 
}

# %%
arrests_df$officer_cnt <- count_all_names(arrests_df$arresting_officers)

# %%
head(arrests_df)
# Out:
#   arrest_date           year month gender race  ethnicity   year_of_birth age
# 1 2019-08-24T02:23:00.0 2019 8     Male   White NonHispanic 1981          37
# 2 2019-08-24T02:02:00.0 2019 8                              1994          25
# 3 2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984          34
# 4 2019-08-24T02:02:00.0 2019 8     Female Black NonHispanic 1984          34
# 5 2019-08-24T02:02:00.0 2019 8     Female Black Unknown     2001          18
# 6 2019-08-24T02:02:00.0 2019 8     Female Black Unknown     2001          18
#   from_address         from_city  from_state   statute_type
# 1 No Permanent Address providence Rhode Island
# 2 SUMMER AVE           Cranston   Rhode Island RI Statute Violation
# 3 DOUGLAS AVE          Providence Rhode Island RI Statute Violation
# 4 DOUGLAS AVE          Providence Rhode Island RI Statute Violation
# 5 TRASH ST                                     RI Statute Violation
# 6 TRASH ST                                     RI Statute Violation
#   statute_code statute_desc                                              counts
# 1                                                                        NA
# 2 31-11-18     Driving after Denial, Suspension or Revocation of License  1
# 3 12-7-10      RESISTING LEGAL OR ILLEGAL ARREST                          1
# 4 11-45-1      DISORDERLY CONDUCT                                         1
# 5 12-7-10      RESISTING LEGAL OR ILLEGAL ARREST                          1
# 6 11-45-1      DISORDERLY CONDUCT                                         1
#   case_number   arresting_officers       id                      officer_cnt
# 1 2019-00084142  YGonzalez, LTaveras     pvd2218242150382148273  2
# 2 2019-00084127  NManfredi               pvd15166785558364246202 1
# 3 2019-00084126  MPlace, JPerez, ASantos pvd3142917706201385905  3
# 4 2019-00084126  MPlace, JPerez, ASantos pvd3142917706201385905  3
# 5 2019-00084126  MPlace, JPerez, ASantos pvd460449304532374599   3
# 6 2019-00084126  MPlace, JPerez, ASantos pvd460449304532374599   3

# %% [markdown]
# ## 3.2 Add Violent Offense Flag

# %%
# Write function to flag alleged violent crimes from the 
# description of of the statute violation

is_violent_offense <- function(v) {

    violent_terms <- c("domestic-asslt", "assault", "battery", "murder")
    n_obs <- length(v)
    is_violent <- rep(FALSE, n_obs)
    
    # iterate over all statute descriptions
    for (i in 1:n_obs) {
        
        # iterate over the 4 terms associated with violence
        for (term in violent_terms) {
            if (!is.na(v[i]) && str_detect(tolower(v[i]), term)) {

                is_violent[i] <- TRUE
            }
        }
    }
    return(is_violent)
}

# %% [markdown]
# ### 3.2.1 Test our Function (always!!)

# %%
vio_vec <- c("DISORDERLY CONDUCT", 
             "RESISTING LEGAL OR ILLEGAL ARREST",
             "DOMESTIC-SIMPLE ASSAULT/BATTERY", 
             "SIMPLE ASSAULT OR BATTERY")

is_violent_offense(vio_vec)    # Should be: FALSE, FALSE, TRUE, TRUE
# Out:
# [1] FALSE FALSE  TRUE  TRUE

# %% [markdown]
# ### 3.2.2 Create `violent` Column in `arrests_df`

# %%
arrests_df$violent <- is_violent_offense(arrests_df$statute_desc)

# %%
tail(arrests_df)
# Out:
#       arrest_date           year month gender race  ethnicity   year_of_birth
# 13007 2021-10-01T00:00:00.0 2021 10    Female White NonHispanic 1979
# 13008 2021-10-01T00:00:00.0 2021 10    Female White NonHispanic 1979
# 13009 2021-10-01T00:00:00.0 2021 10    Female White NonHispanic 1979
# 13010 2021-10-01T00:00:00.0 2021 10    Female White NonHispanic 1979
# 13011 2021-10-01T00:05:00.0 2021 10    Male   Black Hispanic    1952
# 13012 2021-10-01T00:00:00.0 2021 10    Male   Black Hispanic    1980
#       age from_address         from_city  from_state   statute_type
# 13007 42  HIGHLAND STREET      PAWTUCLKET NULL         RI Statute Violation
# 13008 42  HIGHLAND STREET      PAWTUCLKET NULL         RI Statute Violation
# 13009 42  HIGHLAND STREET      PAWTUCLKET NULL         RI Statute Violation
# 13010 42  HIGHLAND STREET      PAWTUCLKET NULL         RI Statute Violation
# 13011 68  PHEBE ST             Providence Rhode Island NULL
# 13012 40  No Permanent Address Providence Rhode Island NULL
#       statute_code   statute_desc                             counts
# 13007 21-28-4.01-C1A POSSESSION OF SCHEDULE I II III           1
# 13008 11-5-3         SIMPLE ASSAULT OR BATTERY                 1
# 13009 11-45-1        DISORDERLY CONDUCT                        1
# 13010 11-32-1        OBSTRUCTING OFFICER IN EXECUTION OF DUTY  1
# 13011 NULL           NULL                                     NA
# 13012 NULL           NULL                                     NA
#       case_number
# 13007 2021-00077653
# 13008 2021-00077653
# 13009 2021-00077653
# 13010 2021-00077653
# 13011 2021-00077654
# 13012 2021-00077676
#       arresting_officers
# 13007 Colicci, Nathaniel/ Heeder, Jenna/ Prete, Louis/ Wagoner, Alexander
# 13008 Colicci, Nathaniel/ Heeder, Jenna/ Prete, Louis/ Wagoner, Alexander
# 13009 Colicci, Nathaniel/ Heeder, Jenna/ Prete, Louis/ Wagoner, Alexander
# 13010 Colicci, Nathaniel/ Heeder, Jenna/ Prete, Louis/ Wagoner, Alexander
# 13011 Silva, Eric
# 13012 Cooney, Sean
#       id                      officer_cnt violent
# 13007 pvd10290435390801352104 4           FALSE
# 13008 pvd10290435390801352104 4            TRUE
# 13009 pvd10290435390801352104 4           FALSE
# 13010 pvd10290435390801352104 4           FALSE
# 13011 pvd10501230489459422006 1           FALSE
# 13012 pvd6857941429842573728  1           FALSE

# %% [markdown]
# ## 3.3 Aggregating to _Person-Level_ DataFrame
#
#   - Use the `group_by()` and `summarise()` pattern from _dplyr_ functions

# %%
person_df <- arrests_df %>%
    group_by(id) %>%
    summarise(
        total_charges = n(),
        num_uniq_arrests = length(unique(case_number)),
        prop_violent = mean(violent),
        mean_officer_cnt = mean(officer_cnt),
        age = age[1],
        gender = gender[1]
    )

# %%
head(person_df)
# Out:
#   id                      total_charges num_uniq_arrests prop_violent
# 1 pvd10005240635544439514 2             1                0.0000000
# 2 pvd10005979167793807438 1             1                0.0000000
# 3 pvd10007039892056892673 1             1                0.0000000
# 4 pvd10015003399035869819 7             3                0.1428571
# 5 pvd10015761183771579680 1             1                0.0000000
# 6 pvd10016651127192901464 1             1                1.0000000
#   mean_officer_cnt age gender
# 1 1.000000         21  Female
# 2 2.000000         57  Female
# 3 1.000000         32  Female
# 4 3.571429         40  Female
# 5 2.000000         42  Male
# 6 2.000000         30  Male

# %% [markdown]
# # 4. Intro to _ggplot2_
#   - Operates on `data.frame` objects
#   - Map variables to aesthetics, and then display using "geom" (i.e., "geometric object")
#   - Geom layers can be stack over one another to add information

# %%
ggplot(person_df, aes(x = age))    # does nothing...
# Out:
# plot without title

# %% [markdown]
# ## 4.1 Plotting Histogram of `age`

# %%
ggplot(person_df, aes(x = age)) +
    geom_histogram()   # kinda boring...
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ### 4.1.1 Adding `colour` and `fill` to `geom_histogram()`

# %%
ggplot(person_df, aes(x = age)) +
    geom_histogram(fill = "skyblue", colour = "lightblue", bins = 30)
# Out:
# plot without title

# %% [markdown]
# ## 4.2 Density Plot of `age`

# %%
ggplot(person_df, aes(x = age)) +
    geom_density(fill = "skyblue", colour = "lightblue")
# Out:
# plot without title

# %% [markdown]
# ### 4.2.1 Adjusting `alpha`

# %%
ggplot(person_df, aes(x = age)) + 
    geom_density(fill = "skyblue", colour = "lightblue", alpha = 0.5)
# Out:
# plot without title

# %% [markdown]
# ### 4.2.2 Adding `gender` Variable Aesthetic

# %%
ggplot(person_df, aes(x = age, y = after_stat(count), fill = gender, colour = gender)) +
    geom_density(alpha = 0.4) +
    xlab("Age of Person Arrested") +
    ylab("Count")
# Out:
# plot without title

# %% [markdown]
# ## 4.3 Scatter Plot of `age` and `total_charges`

# %%
ggplot(person_df, aes(x = age, y = total_charges)) + 
    geom_point()
# Out:
# plot without title

# %% [markdown]
# ### 4.3.1 Adjusting `colour` and `alpha`

# %%
ggplot(person_df, aes(x = age, y = total_charges)) +
    geom_point(colour = "skyblue", alpha = 0.6)
# Out:
# plot without title

# %% [markdown]
# ### 4.3.2 Using `geom_jitter` for Scatterplots

# %%
ggplot(person_df, aes(x = age, y = total_charges)) +
    geom_jitter(colour = "purple", alpha = 0.4)
# Out:
# plot without title

# %% [markdown]
# ## 4.4 Plotting `num_uniq_arrests` and `total_charges` with a `stat_smooth()` Layer

# %%
ggplot(person_df, aes(x = num_uniq_arrests, y = total_charges)) +
    geom_jitter(colour = "violet", alpha = 0.4) +
    stat_smooth(method = "lm", formula = y ~ x)
# Out:
# plot without title

# %% [markdown]
# ## 4.5 Adding Third Variable to `aes()`

# %%
ggplot(person_df, aes(x = num_uniq_arrests, y = total_charges, colour = prop_violent)) +
    geom_jitter(alpha = 0.5) + 
    xlim(1, 6) +
    ylim(1, 15)
# Out:
# Warning message:
# “Removed 3820 rows containing missing values (`geom_point()`).”
# plot without title
